# %%
from google_play_scraper import app
from google_play_scraper import reviews, Sort
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews_all

# %%
kor_reviews = reviews_all(
    'com.rummikubfree',
    sleep_milliseconds=0, # defaults to 0
    lang='ko', # defaults to 'en'
    country='kr', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df_busu = pd.DataFrame(np.array(kor_reviews),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))


df_busu.tail()
# Out:
#                                    reviewId    userName  \
# 23021  0526214f-15c3-4c71-a29b-09b379c87df0  Google 사용자
# 23022  cae3ac30-3a28-45a9-a5a5-abfe895bfe52  Google 사용자
# 23023  8ea6dfd2-17c6-4960-aa73-85731c2d801f  Google 사용자
# 23024  4e97b852-c0dd-4775-9c3d-b7a27053d288  Google 사용자
# 23025  3a98a648-7f40-4db5-8103-936e31b4b325  Google 사용자
#
#                                                userImage  \
# 23021  https://play-lh.googleusercontent.com/EGemoI2N...
# 23022  https://play-lh.googleusercontent.com/EGemoI2N...
# 23023  https://play-lh.googleusercontent.com/EGemoI2N...
# 23024  https://play-lh.googleusercontent.com/EGemoI2N...
# 23025  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 23021                           30seconds is too fast!ㅠㅠ      3
# 23022  판이 너무 작아요. 세로 8줄은 되어야 같은색 연속숫자 타일을 보기좋게 배열할 수 ...      1
# 23023         Private games cannot be played rivate game      2
# ...

# %%
df_busu.to_csv('rummikub_board.csv')

# %% [markdown]
# 전략
# 마피아: com.yottagames.mafiawar
# 로드모바일:com.igg.android.lordsmobile
# 클래시로얄:com.supercell.clashroyale
# 액션
# 브롤스타즈:com.supercell.brawlstars
# 배틀그라운드:com.pubg.krmobile
# 붕괴: com.miHoYo.bh3korea
# 어드벤쳐
# 포켓몬:com.nianticlabs.pokemongo
# 제5인격:com.netease.idv.googleplay
# roblox:com.roblox.client
# 자동차
# 아스팔트9:com.gameloft.android.ANMP.GloftA9HM
# 카트라이더:com.nexon.kart
# 스포츠
# 피파:com.nexon.fo4m
# 프로야구: com.com2us.probaseball3d.normal.freefull.google.global.android.common
# 이사만루:com.gonggames.kbo3.aos.google.kr
# 카지노
# 피망포커:com.neowiz.games.poker
# 윈조이: com.netmarble.mpoker
# 한게임:com.nhnent.Qpoker
# 보드
# 모마:com.cjenm.ModooMarbleKakao
# 프마:com.readynine.bigpot999
